# %%
import cv2
import os

def extract_and_resize_frames(video_path, output_folder, frame_size=(64, 64)):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    # Capture the video
    video_capture = cv2.VideoCapture(video_path)
    # Check if video opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    frame_number = 0
    while True:
        # Read a frame
        ret, frame = video_capture.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, frame_size)

        # Save the frame as an image file
        frame_filename = os.path.join(output_folder, f"frame_{frame_number:04d}.png")
        cv2.imwrite(frame_filename, resized_frame)

        # Print the status
        print(f"Extracted and resized frame {frame_number}")

        frame_number += 1

    # Release the video capture object
    video_capture.release()
    print("Done extracting and resizing frames.")

# Example usage
video_path = '/content/of_1.mp4'
output_folder = 'output_frames'
extract_and_resize_frames(video_path, output_folder)
# Out:
# Extracted and resized frame 0
# Extracted and resized frame 1
# Extracted and resized frame 2
# Extracted and resized frame 3
# Extracted and resized frame 4
# Extracted and resized frame 5
# Extracted and resized frame 6
# Extracted and resized frame 7
# Extracted and resized frame 8
# Extracted and resized frame 9
# Extracted and resized frame 10
# Extracted and resized frame 11
# Extracted and resized frame 12
# Extracted and resized frame 13
# Extracted and resized frame 14
# Extracted and resized frame 15
# Extracted and resized frame 16
# Extracted and resized frame 17
# Extracted and resized frame 18
# Extracted and resized frame 19
# Extracted and resized frame 20
# Extracted and resized frame 21
# Extracted and resized frame 22
# Extracted and resized frame 23
# Extracted and resized frame 24
# Extracted and resized frame 25
# Extracted and resized frame 26
# Extracted and resized frame 27
# Extracted and resized frame 28
# Extracted and resized frame 29
# Extracted and resized frame 30
# Extracted and resized frame 31
# Extracted and resized frame 32
# Extracted and resized frame 33
# Extracted and resized frame 34
# Extracted and resized frame 35
# Extracted and resized frame 36
# Extracted and resized frame 37
# Extracted and resized frame 38
# Extracted and resized frame 39
# Extracted and resized frame 40
# Extracted and resized frame 41
# Extracted and resized frame 42
# Extracted and resized frame 43
# Extracted and resized frame 44
# Extracted and resized frame 45
# Extracted and resized frame 46
# Extracted and resized frame 47
# Extracted and resized frame 48
# Extracted and resized frame 49
# Extracted and resized frame 50
# Extracted and resized frame 51
# Extracted and resized frame 52
# Extracted and resized frame 53
# Extracted and resized frame 54
# Extracted and resized frame 55
# Extracted and resized frame 56
# Extracted and resized frame 57
# Extracted and resized frame 58
# Extracted and resized frame 59
# Extracted and resized frame 60
# Extracted and resized frame 61
# Extracted and resized frame 62
# Extracted and resized frame 63
# Extracted and resized frame 64
# Extracted and resized frame 65
# Extracted and resized frame 66
# Extracted and resized frame 67
# Extracted and resized frame 68
# Extracted and resized frame 69
# Extracted and resized frame 70
# Extracted and resized frame 71
# Extracted and resized frame 72
# Extracted and resized frame 73
# Extracted and resized frame 74
# Extracted and resized frame 75
# Extracted and resized frame 76
# Extracted and resized frame 77
# Extracted and resized frame 78
# Extracted and resized frame 79
# Extracted and resized frame 80
# Extracted and resized frame 81
# Extracted and resized frame 82
# Extracted and resized frame 83
# Extracted and resized frame 84
# Extracted and resized frame 85
# Extracted and resized frame 86
# Extracted and resized frame 87
# Extracted and resized frame 88
# Extracted and resized frame 89
# Extracted and resized frame 90
# Extracted and resized frame 91
# Extracted and resized frame 92
# Extracted and resized frame 93
# Extracted and resized frame 94
# Extracted and resized frame 95
# Extracted and resized frame 96
# Extracted and resized frame 97
# Extracted and resized frame 98
# Extracted and resized frame 99
# Extracted and resized frame 100
# Extracted and resized frame 101
# Extracted and resized frame 102
# Extracted and resized frame 103
# Extracted and resized frame 104
# Extracted and resized frame 105
# Extracted and resized frame 106
# Extracted and resized frame 107
# Extracted and resized frame 108
# Extracted and resized frame 109
# Extracted and resized frame 110
# Extracted and resized frame 111
# Extracted and resized frame 112
# Extracted and resized frame 113
# Extracted and resized frame 114
# Extracted and resized frame 115
# Extracted and resized frame 116
# Extracted and resized frame 117
# Extracted and resized frame 118
# Extracted and resized frame 119
# Extracted and resized frame 120
# Extracted and resized frame 121
# Extracted and resized frame 122
# Extracted and resized frame 123
# Extracted and resized frame 124
# Extracted and resized frame 125
# Extracted and resized frame 126
# Extracted and resized frame 127
# Extracted and resized frame 128
# Extracted and resized frame 129
# Extracted and resized frame 130
# Extracted and resized frame 131
# Extracted and resized frame 132
# Extracted and resized frame 133
# Extracted and resized frame 134
# Extracted and resized frame 135
# Extracted and resized frame 136
# Extracted and resized frame 137
# Extracted and resized frame 138
# Extracted and resized frame 139
# Extracted and resized frame 140
# Extracted and resized frame 141
# Extracted and resized frame 142
# Extracted and resized frame 143
# Extracted and resized frame 144
# Extracted and resized frame 145
# Extracted and resized frame 146
# Extracted and resized frame 147
# Extracted and resized frame 148
# Extracted and resized frame 149
# Extracted and resized frame 150
# Extracted and resized frame 151
# Extracted and resized frame 152
# Extracted and resized frame 153
# Extracted and resized frame 154
# Extracted and resized frame 155
# Extracted and resized frame 156
# Extracted and resized frame 157
# Extracted and resized frame 158
# Extracted and resized frame 159
# Extracted and resized frame 160
# Extracted and resized frame 161
# Extracted and resized frame 162
# Extracted and resized frame 163
# Extracted and resized frame 164
# Extracted and resized frame 165
# Extracted and resized frame 166
# Extracted and resized frame 167
# Extracted and resized frame 168
# Extracted and resized frame 169
# Extracted and resized frame 170
# Extracted and resized frame 171
# Extracted and resized frame 172
# Extracted and resized frame 173
# Extracted and resized frame 174
# Extracted and resized frame 175
# Extracted and resized frame 176
# Extracted and resized frame 177
# Extracted and resized frame 178
# Extracted and resized frame 179
# Extracted and resized frame 180
# Extracted and resized frame 181
# Extracted and resized frame 182
# Extracted and resized frame 183
# Extracted and resized frame 184
# Extracted and resized frame 185
# Extracted and resized frame 186
# Extracted and resized frame 187
# Extracted and resized frame 188
# Extracted and resized frame 189
# Extracted and resized frame 190
# Extracted and resized frame 191
# Extracted and resized frame 192
# Extracted and resized frame 193
# Extracted and resized frame 194
# Extracted and resized frame 195
# Extracted and resized frame 196
# Extracted and resized frame 197
# Extracted and resized frame 198
# Extracted and resized frame 199
# Extracted and resized frame 200
# Extracted and resized frame 201
# Extracted and resized frame 202
# Extracted and resized frame 203
# Extracted and resized frame 204
# Extracted and resized frame 205
# Extracted and resized frame 206
# Extracted and resized frame 207
# Extracted and resized frame 208
# Extracted and resized frame 209
# Extracted and resized frame 210
# Extracted and resized frame 211
# Extracted and resized frame 212
# Extracted and resized frame 213
# Extracted and resized frame 214
# Extracted and resized frame 215
# Extracted and resized frame 216
# Extracted and resized frame 217
# Extracted and resized frame 218
# Extracted and resized frame 219
# Extracted and resized frame 220
# Extracted and resized frame 221
# Extracted and resized frame 222
# Extracted and resized frame 223
# Extracted and resized frame 224
# Extracted and resized frame 225
# Extracted and resized frame 226
# Extracted and resized frame 227
# Extracted and resized frame 228
# Extracted and resized frame 229
# Extracted and resized frame 230
# Extracted and resized frame 231
# Extracted and resized frame 232
# Extracted and resized frame 233
# Extracted and resized frame 234
# Extracted and resized frame 235
# Extracted and resized frame 236
# Extracted and resized frame 237
# Extracted and resized frame 238
# Extracted and resized frame 239
# Extracted and resized frame 240
# Extracted and resized frame 241
# Extracted and resized frame 242
# Extracted and resized frame 243
# Extracted and resized frame 244
# Extracted and resized frame 245
# Extracted and resized frame 246
# Extracted and resized frame 247
# Extracted and resized frame 248
# Extracted and resized frame 249
# Extracted and resized frame 250
# Extracted and resized frame 251
# Extracted and resized frame 252
# Extracted and resized frame 253
# Extracted and resized frame 254
# Extracted and resized frame 255
# Extracted and resized frame 256
# Extracted and resized frame 257
# Extracted and resized frame 258
# Extracted and resized frame 259
# Extracted and resized frame 260
# Extracted and resized frame 261
# Extracted and resized frame 262
# Extracted and resized frame 263
# Extracted and resized frame 264
# Extracted and resized frame 265
# Extracted and resized frame 266
# Extracted and resized frame 267
# Extracted and resized frame 268
# Extracted and resized frame 269
# Extracted and resized frame 270
# Extracted and resized frame 271
# Extracted and resized frame 272
# Extracted and resized frame 273
# Extracted and resized frame 274
# Extracted and resized frame 275
# Extracted and resized frame 276
# Extracted and resized frame 277
# Extracted and resized frame 278
# Extracted and resized frame 279
# Extracted and resized frame 280
# Extracted and resized frame 281
# Extracted and resized frame 282
# Extracted and resized frame 283
# Extracted and resized frame 284
# Extracted and resized frame 285
# Extracted and resized frame 286
# Extracted and resized frame 287
# Extracted and resized frame 288
# Extracted and resized frame 289
# Extracted and resized frame 290
# Extracted and resized frame 291
# Extracted and resized frame 292
# Extracted and resized frame 293
# Extracted and resized frame 294
# Extracted and resized frame 295
# Extracted and resized frame 296
# Extracted and resized frame 297
# Extracted and resized frame 298
# Extracted and resized frame 299
# Extracted and resized frame 300
# Extracted and resized frame 301
# Extracted and resized frame 302
# Extracted and resized frame 303
# Extracted and resized frame 304
# Extracted and resized frame 305
# Extracted and resized frame 306
# Extracted and resized frame 307
# Extracted and resized frame 308
# Extracted and resized frame 309
# Extracted and resized frame 310
# Extracted and resized frame 311
# Extracted and resized frame 312
# Extracted and resized frame 313
# Extracted and resized frame 314
# Extracted and resized frame 315
# Extracted and resized frame 316
# Extracted and resized frame 317
# Extracted and resized frame 318
# Extracted and resized frame 319
# Extracted and resized frame 320
# Extracted and resized frame 321
# Extracted and resized frame 322
# Extracted and resized frame 323
# Extracted and resized frame 324
# Extracted and resized frame 325
# Extracted and resized frame 326
# Extracted and resized frame 327
# Extracted and resized frame 328
# Extracted and resized frame 329
# Extracted and resized frame 330
# Extracted and resized frame 331
# Extracted and resized frame 332
# Extracted and resized frame 333
# Extracted and resized frame 334
# Extracted and resized frame 335
# Extracted and resized frame 336
# Extracted and resized frame 337
# Extracted and resized frame 338
# Extracted and resized frame 339
# Extracted and resized frame 340
# Extracted and resized frame 341
# Extracted and resized frame 342
# Extracted and resized frame 343
# Extracted and resized frame 344
# Extracted and resized frame 345
# Extracted and resized frame 346
# Extracted and resized frame 347
# Extracted and resized frame 348
# Extracted and resized frame 349
# Extracted and resized frame 350
# Extracted and resized frame 351
# Extracted and resized frame 352
# Extracted and resized frame 353
# Extracted and resized frame 354
# Extracted and resized frame 355
# Extracted and resized frame 356
# Extracted and resized frame 357
# Extracted and resized frame 358
# Extracted and resized frame 359
# Extracted and resized frame 360
# Extracted and resized frame 361
# Extracted and resized frame 362
# Extracted and resized frame 363
# Extracted and resized frame 364
# Extracted and resized frame 365
# Extracted and resized frame 366
# Extracted and resized frame 367
# Extracted and resized frame 368
# Extracted and resized frame 369
# Extracted and resized frame 370
# Extracted and resized frame 371
# Extracted and resized frame 372
# Extracted and resized frame 373
# Extracted and resized frame 374
# Extracted and resized frame 375
# Extracted and resized frame 376
# Extracted and resized frame 377
# Extracted and resized frame 378
# Extracted and resized frame 379
# Extracted and resized frame 380
# Extracted and resized frame 381
# Extracted and resized frame 382
# Extracted and resized frame 383
# Extracted and resized frame 384
# Extracted and resized frame 385
# Extracted and resized frame 386
# Extracted and resized frame 387
# Extracted and resized frame 388
# Extracted and resized frame 389
# Extracted and resized frame 390
# Extracted and resized frame 391
# Extracted and resized frame 392
# Extracted and resized frame 393
# Extracted and resized frame 394
# Extracted and resized frame 395
# Extracted and resized frame 396
# Extracted and resized frame 397
# Extracted and resized frame 398
# Extracted and resized frame 399
# Extracted and resized frame 400
# Extracted and resized frame 401
# Extracted and resized frame 402
# Extracted and resized frame 403
# Extracted and resized frame 404
# Extracted and resized frame 405
# Extracted and resized frame 406
# Extracted and resized frame 407
# Extracted and resized frame 408
# Extracted and resized frame 409
# Extracted and resized frame 410
# Extracted and resized frame 411
# Extracted and resized frame 412
# Extracted and resized frame 413
# Extracted and resized frame 414
# Extracted and resized frame 415
# Extracted and resized frame 416
# Extracted and resized frame 417
# Extracted and resized frame 418
# Extracted and resized frame 419
# Extracted and resized frame 420
# Extracted and resized frame 421
# Extracted and resized frame 422
# Extracted and resized frame 423
# Extracted and resized frame 424
# Extracted and resized frame 425
# Extracted and resized frame 426
# Extracted and resized frame 427
# Extracted and resized frame 428
# Extracted and resized frame 429
# Extracted and resized frame 430
# Extracted and resized frame 431
# Extracted and resized frame 432
# Extracted and resized frame 433
# Extracted and resized frame 434
# Extracted and resized frame 435
# Extracted and resized frame 436
# Extracted and resized frame 437
# Extracted and resized frame 438
# Extracted and resized frame 439
# Extracted and resized frame 440
# Extracted and resized frame 441
# Extracted and resized frame 442
# Extracted and resized frame 443
# Extracted and resized frame 444
# Extracted and resized frame 445
# Extracted and resized frame 446
# Extracted and resized frame 447
# Extracted and resized frame 448
# Extracted and resized frame 449
# Extracted and resized frame 450
# Extracted and resized frame 451
# Extracted and resized frame 452
# Extracted and resized frame 453
# Extracted and resized frame 454
# Extracted and resized frame 455
# Extracted and resized frame 456
# Extracted and resized frame 457
# Extracted and resized frame 458
# Extracted and resized frame 459
# Extracted and resized frame 460
# Extracted and resized frame 461
# Extracted and resized frame 462
# Extracted and resized frame 463
# Extracted and resized frame 464
# Extracted and resized frame 465
# Extracted and resized frame 466
# Extracted and resized frame 467
# Extracted and resized frame 468
# Extracted and resized frame 469
# Extracted and resized frame 470
# Extracted and resized frame 471
# Extracted and resized frame 472
# Extracted and resized frame 473
# Extracted and resized frame 474
# Extracted and resized frame 475
# Extracted and resized frame 476
# Extracted and resized frame 477
# Extracted and resized frame 478
# Extracted and resized frame 479
# Extracted and resized frame 480
# Extracted and resized frame 481
# Extracted and resized frame 482
# Extracted and resized frame 483
# Extracted and resized frame 484
# Extracted and resized frame 485
# Extracted and resized frame 486
# Extracted and resized frame 487
# Extracted and resized frame 488
# Extracted and resized frame 489
# Extracted and resized frame 490
# Extracted and resized frame 491
# Extracted and resized frame 492
# Extracted and resized frame 493
# Extracted and resized frame 494
# Extracted and resized frame 495
# Extracted and resized frame 496
# Extracted and resized frame 497
# Extracted and resized frame 498
# Extracted and resized frame 499
# Extracted and resized frame 500
# Extracted and resized frame 501
# Extracted and resized frame 502
# Extracted and resized frame 503
# Extracted and resized frame 504
# Extracted and resized frame 505
# Extracted and resized frame 506
# Extracted and resized frame 507
# Extracted and resized frame 508
# Extracted and resized frame 509
# Extracted and resized frame 510
# Extracted and resized frame 511
# Extracted and resized frame 512
# Extracted and resized frame 513
# Extracted and resized frame 514
# Extracted and resized frame 515
# Extracted and resized frame 516
# Extracted and resized frame 517
# Extracted and resized frame 518
# Extracted and resized frame 519
# Extracted and resized frame 520
# Extracted and resized frame 521
# Extracted and resized frame 522
# Extracted and resized frame 523
# Extracted and resized frame 524
# Extracted and resized frame 525
# Extracted and resized frame 526
# Extracted and resized frame 527
# Extracted and resized frame 528
# Extracted and resized frame 529
# Extracted and resized frame 530
# Extracted and resized frame 531
# Extracted and resized frame 532
# Extracted and resized frame 533
# Extracted and resized frame 534
# Extracted and resized frame 535
# Extracted and resized frame 536
# Extracted and resized frame 537
# Extracted and resized frame 538
# Extracted and resized frame 539
# Extracted and resized frame 540
# Extracted and resized frame 541
# Extracted and resized frame 542
# Extracted and resized frame 543
# Extracted and resized frame 544
# Extracted and resized frame 545
# Extracted and resized frame 546
# Extracted and resized frame 547
# Extracted and resized frame 548
# Extracted and resized frame 549
# Extracted and resized frame 550
# Extracted and resized frame 551
# Extracted and resized frame 552
# Extracted and resized frame 553
# Extracted and resized frame 554
# Extracted and resized frame 555
# Extracted and resized frame 556
# Extracted and resized frame 557
# Extracted and resized frame 558
# Extracted and resized frame 559
# Extracted and resized frame 560
# Extracted and resized frame 561
# Extracted and resized frame 562
# Extracted and resized frame 563
# Extracted and resized frame 564
# Extracted and resized frame 565
# Extracted and resized frame 566
# Extracted and resized frame 567
# Extracted and resized frame 568
# Extracted and resized frame 569
# Extracted and resized frame 570
# Extracted and resized frame 571
# Extracted and resized frame 572
# Extracted and resized frame 573
# Extracted and resized frame 574
# Extracted and resized frame 575
# Extracted and resized frame 576
# Extracted and resized frame 577
# Extracted and resized frame 578
# Extracted and resized frame 579
# Extracted and resized frame 580
# Extracted and resized frame 581
# Extracted and resized frame 582
# Extracted and resized frame 583
# Extracted and resized frame 584
# Extracted and resized frame 585
# Extracted and resized frame 586
# Extracted and resized frame 587
# Extracted and resized frame 588
# Extracted and resized frame 589
# Extracted and resized frame 590
# Extracted and resized frame 591
# Extracted and resized frame 592
# Extracted and resized frame 593
# Extracted and resized frame 594
# Extracted and resized frame 595
# Extracted and resized frame 596
# Extracted and resized frame 597
# Extracted and resized frame 598
# Extracted and resized frame 599
# Extracted and resized frame 600
# Extracted and resized frame 601
# Extracted and resized frame 602
# Extracted and resized frame 603
# Extracted and resized frame 604
# Extracted and resized frame 605
# Extracted and resized frame 606
# Extracted and resized frame 607
# Extracted and resized frame 608
# Extracted and resized frame 609
# Extracted and resized frame 610
# Extracted and resized frame 611
# Extracted and resized frame 612
# Extracted and resized frame 613
# Extracted and resized frame 614
# Extracted and resized frame 615
# Extracted and resized frame 616
# Extracted and resized frame 617
# Extracted and resized frame 618
# Extracted and resized frame 619
# Extracted and resized frame 620
# Extracted and resized frame 621
# Extracted and resized frame 622
# Extracted and resized frame 623
# Extracted and resized frame 624
# Extracted and resized frame 625
# Extracted and resized frame 626
# Extracted and resized frame 627
# Extracted and resized frame 628
# Extracted and resized frame 629
# Extracted and resized frame 630
# Extracted and resized frame 631
# Extracted and resized frame 632
# Extracted and resized frame 633
# Extracted and resized frame 634
# Extracted and resized frame 635
# Extracted and resized frame 636
# Extracted and resized frame 637
# Extracted and resized frame 638
# Extracted and resized frame 639
# Extracted and resized frame 640
# Extracted and resized frame 641
# Extracted and resized frame 642
# Extracted and resized frame 643
# Extracted and resized frame 644
# Extracted and resized frame 645
# Extracted and resized frame 646
# Extracted and resized frame 647
# Extracted and resized frame 648
# Extracted and resized frame 649
# Extracted and resized frame 650
# Extracted and resized frame 651
# Extracted and resized frame 652
# Extracted and resized frame 653
# Extracted and resized frame 654
# Extracted and resized frame 655
# Extracted and resized frame 656
# Extracted and resized frame 657
# Extracted and resized frame 658
# Extracted and resized frame 659
# Extracted and resized frame 660
# Extracted and resized frame 661
# Extracted and resized frame 662
# Extracted and resized frame 663
# Extracted and resized frame 664
# Extracted and resized frame 665
# Extracted and resized frame 666
# Extracted and resized frame 667
# Extracted and resized frame 668
# Extracted and resized frame 669
# Extracted and resized frame 670
# Extracted and resized frame 671
# Extracted and resized frame 672
# Extracted and resized frame 673
# Extracted and resized frame 674
# Extracted and resized frame 675
# Extracted and resized frame 676
# Extracted and resized frame 677
# Extracted and resized frame 678
# Extracted and resized frame 679
# Extracted and resized frame 680
# Extracted and resized frame 681
# Extracted and resized frame 682
# Extracted and resized frame 683
# Extracted and resized frame 684
# Extracted and resized frame 685
# Extracted and resized frame 686
# Extracted and resized frame 687
# Extracted and resized frame 688
# Extracted and resized frame 689
# Extracted and resized frame 690
# Extracted and resized frame 691
# Extracted and resized frame 692
# Extracted and resized frame 693
# Extracted and resized frame 694
# Extracted and resized frame 695
# Extracted and resized frame 696
# Extracted and resized frame 697
# Extracted and resized frame 698
# Extracted and resized frame 699
# Extracted and resized frame 700
# Extracted and resized frame 701
# Extracted and resized frame 702
# Extracted and resized frame 703
# Extracted and resized frame 704
# Extracted and resized frame 705
# Extracted and resized frame 706
# Extracted and resized frame 707
# Extracted and resized frame 708
# Extracted and resized frame 709
# Extracted and resized frame 710
# Extracted and resized frame 711
# Extracted and resized frame 712
# Extracted and resized frame 713
# Extracted and resized frame 714
# Extracted and resized frame 715
# Extracted and resized frame 716
# Extracted and resized frame 717
# Extracted and resized frame 718
# Extracted and resized frame 719
# Extracted and resized frame 720
# Extracted and resized frame 721
# Extracted and resized frame 722
# Extracted and resized frame 723
# Extracted and resized frame 724
# Extracted and resized frame 725
# Extracted and resized frame 726
# Extracted and resized frame 727
# Extracted and resized frame 728
# Extracted and resized frame 729
# Extracted and resized frame 730
# Extracted and resized frame 731
# Extracted and resized frame 732
# Extracted and resized frame 733
# Extracted and resized frame 734
# Extracted and resized frame 735
# Extracted and resized frame 736
# Extracted and resized frame 737
# Extracted and resized frame 738
# Extracted and resized frame 739
# Extracted and resized frame 740
# Extracted and resized frame 741
# Extracted and resized frame 742
# Extracted and resized frame 743
# Extracted and resized frame 744
# Extracted and resized frame 745
# Extracted and resized frame 746
# Extracted and resized frame 747
# Extracted and resized frame 748
# Extracted and resized frame 749
# Extracted and resized frame 750
# Extracted and resized frame 751
# Extracted and resized frame 752
# Extracted and resized frame 753
# Extracted and resized frame 754
# Extracted and resized frame 755
# Extracted and resized frame 756
# Extracted and resized frame 757
# Extracted and resized frame 758
# Extracted and resized frame 759
# Extracted and resized frame 760
# Extracted and resized frame 761
# Extracted and resized frame 762
# Extracted and resized frame 763
# Extracted and resized frame 764
# Extracted and resized frame 765
# Extracted and resized frame 766
# Extracted and resized frame 767
# Extracted and resized frame 768
# Done extracting and resizing frames.

# %%
import cv2
import os
import math

def extract_and_resize_frames(video_path, output_folder, frame_count=250, frame_size=(64, 64)):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Capture the video
    video_capture = cv2.VideoCapture(video_path)

    # Check if video opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total number of frames in the video: {total_frames}")

    # Calculate the interval to evenly space the frame_count frames
    interval = max(1, total_frames // frame_count)
    print(f"Frame extraction interval: {interval}")

    frame_number = 0
    extracted_frames = 0

    while extracted_frames < frame_count and frame_number < total_frames:
        # Set the position of the next frame to read
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

        # Read the frame
        ret, frame = video_capture.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, frame_size)

        # Save the frame as an image file
        frame_filename = os.path.join(output_folder, f"lp_{extracted_frames:04d}.png")
        cv2.imwrite(frame_filename, resized_frame)

        # Print the status
        print(f"Extracted and resized frame {extracted_frames + 1} of {frame_count}")

        extracted_frames += 1
        frame_number += interval

    # Release the video capture object
    video_capture.release()
    print("Done extracting and resizing frames.")

# Example usage
video_path = '/content/left_palm.mp4'
output_folder = 'left_palm_frames'
extract_and_resize_frames(video_path, output_folder)
# Out:
# Total number of frames in the video: 531
# Frame extraction interval: 2
# Extracted and resized frame 1 of 250
# Extracted and resized frame 2 of 250
# Extracted and resized frame 3 of 250
# Extracted and resized frame 4 of 250
# Extracted and resized frame 5 of 250
# Extracted and resized frame 6 of 250
# Extracted and resized frame 7 of 250
# Extracted and resized frame 8 of 250
# Extracted and resized frame 9 of 250
# Extracted and resized frame 10 of 250
# Extracted and resized frame 11 of 250
# Extracted and resized frame 12 of 250
# Extracted and resized frame 13 of 250
# Extracted and resized frame 14 of 250
# Extracted and resized frame 15 of 250
# Extracted and resized frame 16 of 250
# Extracted and resized frame 17 of 250
# Extracted and resized frame 18 of 250
# Extracted and resized frame 19 of 250
# Extracted and resized frame 20 of 250
# Extracted and resized frame 21 of 250
# Extracted and resized frame 22 of 250
# Extracted and resized frame 23 of 250
# Extracted and resized frame 24 of 250
# Extracted and resized frame 25 of 250
# Extracted and resized frame 26 of 250
# Extracted and resized frame 27 of 250
# Extracted and resized frame 28 of 250
# Extracted and resized frame 29 of 250
# Extracted and resized frame 30 of 250
# Extracted and resized frame 31 of 250
# Extracted and resized frame 32 of 250
# Extracted and resized frame 33 of 250
# Extracted and resized frame 34 of 250
# Extracted and resized frame 35 of 250
# Extracted and resized frame 36 of 250
# Extracted and resized frame 37 of 250
# Extracted and resized frame 38 of 250
# Extracted and resized frame 39 of 250
# Extracted and resized frame 40 of 250
# Extracted and resized frame 41 of 250
# Extracted and resized frame 42 of 250
# Extracted and resized frame 43 of 250
# Extracted and resized frame 44 of 250
# Extracted and resized frame 45 of 250
# Extracted and resized frame 46 of 250
# Extracted and resized frame 47 of 250
# Extracted and resized frame 48 of 250
# Extracted and resized frame 49 of 250
# Extracted and resized frame 50 of 250
# Extracted and resized frame 51 of 250
# Extracted and resized frame 52 of 250
# Extracted and resized frame 53 of 250
# Extracted and resized frame 54 of 250
# Extracted and resized frame 55 of 250
# Extracted and resized frame 56 of 250
# Extracted and resized frame 57 of 250
# Extracted and resized frame 58 of 250
# Extracted and resized frame 59 of 250
# Extracted and resized frame 60 of 250
# Extracted and resized frame 61 of 250
# Extracted and resized frame 62 of 250
# Extracted and resized frame 63 of 250
# Extracted and resized frame 64 of 250
# Extracted and resized frame 65 of 250
# Extracted and resized frame 66 of 250
# Extracted and resized frame 67 of 250
# Extracted and resized frame 68 of 250
# Extracted and resized frame 69 of 250
# Extracted and resized frame 70 of 250
# Extracted and resized frame 71 of 250
# Extracted and resized frame 72 of 250
# Extracted and resized frame 73 of 250
# Extracted and resized frame 74 of 250
# Extracted and resized frame 75 of 250
# Extracted and resized frame 76 of 250
# Extracted and resized frame 77 of 250
# Extracted and resized frame 78 of 250
# Extracted and resized frame 79 of 250
# Extracted and resized frame 80 of 250
# Extracted and resized frame 81 of 250
# Extracted and resized frame 82 of 250
# Extracted and resized frame 83 of 250
# Extracted and resized frame 84 of 250
# Extracted and resized frame 85 of 250
# Extracted and resized frame 86 of 250
# Extracted and resized frame 87 of 250
# Extracted and resized frame 88 of 250
# Extracted and resized frame 89 of 250
# Extracted and resized frame 90 of 250
# Extracted and resized frame 91 of 250
# Extracted and resized frame 92 of 250
# Extracted and resized frame 93 of 250
# Extracted and resized frame 94 of 250
# Extracted and resized frame 95 of 250
# Extracted and resized frame 96 of 250
# Extracted and resized frame 97 of 250
# Extracted and resized frame 98 of 250
# Extracted and resized frame 99 of 250
# Extracted and resized frame 100 of 250
# Extracted and resized frame 101 of 250
# Extracted and resized frame 102 of 250
# Extracted and resized frame 103 of 250
# Extracted and resized frame 104 of 250
# Extracted and resized frame 105 of 250
# Extracted and resized frame 106 of 250
# Extracted and resized frame 107 of 250
# Extracted and resized frame 108 of 250
# Extracted and resized frame 109 of 250
# Extracted and resized frame 110 of 250
# Extracted and resized frame 111 of 250
# Extracted and resized frame 112 of 250
# Extracted and resized frame 113 of 250
# Extracted and resized frame 114 of 250
# Extracted and resized frame 115 of 250
# Extracted and resized frame 116 of 250
# Extracted and resized frame 117 of 250
# Extracted and resized frame 118 of 250
# Extracted and resized frame 119 of 250
# Extracted and resized frame 120 of 250
# Extracted and resized frame 121 of 250
# Extracted and resized frame 122 of 250
# Extracted and resized frame 123 of 250
# Extracted and resized frame 124 of 250
# Extracted and resized frame 125 of 250
# Extracted and resized frame 126 of 250
# Extracted and resized frame 127 of 250
# Extracted and resized frame 128 of 250
# Extracted and resized frame 129 of 250
# Extracted and resized frame 130 of 250
# Extracted and resized frame 131 of 250
# Extracted and resized frame 132 of 250
# Extracted and resized frame 133 of 250
# Extracted and resized frame 134 of 250
# Extracted and resized frame 135 of 250
# Extracted and resized frame 136 of 250
# Extracted and resized frame 137 of 250
# Extracted and resized frame 138 of 250
# Extracted and resized frame 139 of 250
# Extracted and resized frame 140 of 250
# Extracted and resized frame 141 of 250
# Extracted and resized frame 142 of 250
# Extracted and resized frame 143 of 250
# Extracted and resized frame 144 of 250
# Extracted and resized frame 145 of 250
# Extracted and resized frame 146 of 250
# Extracted and resized frame 147 of 250
# Extracted and resized frame 148 of 250
# Extracted and resized frame 149 of 250
# Extracted and resized frame 150 of 250
# Extracted and resized frame 151 of 250
# Extracted and resized frame 152 of 250
# Extracted and resized frame 153 of 250
# Extracted and resized frame 154 of 250
# Extracted and resized frame 155 of 250
# Extracted and resized frame 156 of 250
# Extracted and resized frame 157 of 250
# Extracted and resized frame 158 of 250
# Extracted and resized frame 159 of 250
# Extracted and resized frame 160 of 250
# Extracted and resized frame 161 of 250
# Extracted and resized frame 162 of 250
# Extracted and resized frame 163 of 250
# Extracted and resized frame 164 of 250
# Extracted and resized frame 165 of 250
# Extracted and resized frame 166 of 250
# Extracted and resized frame 167 of 250
# Extracted and resized frame 168 of 250
# Extracted and resized frame 169 of 250
# Extracted and resized frame 170 of 250
# Extracted and resized frame 171 of 250
# Extracted and resized frame 172 of 250
# Extracted and resized frame 173 of 250
# Extracted and resized frame 174 of 250
# Extracted and resized frame 175 of 250
# Extracted and resized frame 176 of 250
# Extracted and resized frame 177 of 250
# Extracted and resized frame 178 of 250
# Extracted and resized frame 179 of 250
# Extracted and resized frame 180 of 250
# Extracted and resized frame 181 of 250
# Extracted and resized frame 182 of 250
# Extracted and resized frame 183 of 250
# Extracted and resized frame 184 of 250
# Extracted and resized frame 185 of 250
# Extracted and resized frame 186 of 250
# Extracted and resized frame 187 of 250
# Extracted and resized frame 188 of 250
# Extracted and resized frame 189 of 250
# Extracted and resized frame 190 of 250
# Extracted and resized frame 191 of 250
# Extracted and resized frame 192 of 250
# Extracted and resized frame 193 of 250
# Extracted and resized frame 194 of 250
# Extracted and resized frame 195 of 250
# Extracted and resized frame 196 of 250
# Extracted and resized frame 197 of 250
# Extracted and resized frame 198 of 250
# Extracted and resized frame 199 of 250
# Extracted and resized frame 200 of 250
# Extracted and resized frame 201 of 250
# Extracted and resized frame 202 of 250
# Extracted and resized frame 203 of 250
# Extracted and resized frame 204 of 250
# Extracted and resized frame 205 of 250
# Extracted and resized frame 206 of 250
# Extracted and resized frame 207 of 250
# Extracted and resized frame 208 of 250
# Extracted and resized frame 209 of 250
# Extracted and resized frame 210 of 250
# Extracted and resized frame 211 of 250
# Extracted and resized frame 212 of 250
# Extracted and resized frame 213 of 250
# Extracted and resized frame 214 of 250
# Extracted and resized frame 215 of 250
# Extracted and resized frame 216 of 250
# Extracted and resized frame 217 of 250
# Extracted and resized frame 218 of 250
# Extracted and resized frame 219 of 250
# Extracted and resized frame 220 of 250
# Extracted and resized frame 221 of 250
# Extracted and resized frame 222 of 250
# Extracted and resized frame 223 of 250
# Extracted and resized frame 224 of 250
# Extracted and resized frame 225 of 250
# Extracted and resized frame 226 of 250
# Extracted and resized frame 227 of 250
# Extracted and resized frame 228 of 250
# Extracted and resized frame 229 of 250
# Extracted and resized frame 230 of 250
# Extracted and resized frame 231 of 250
# Extracted and resized frame 232 of 250
# Extracted and resized frame 233 of 250
# Extracted and resized frame 234 of 250
# Extracted and resized frame 235 of 250
# Extracted and resized frame 236 of 250
# Extracted and resized frame 237 of 250
# Extracted and resized frame 238 of 250
# Extracted and resized frame 239 of 250
# Extracted and resized frame 240 of 250
# Extracted and resized frame 241 of 250
# Extracted and resized frame 242 of 250
# Extracted and resized frame 243 of 250
# Extracted and resized frame 244 of 250
# Extracted and resized frame 245 of 250
# Extracted and resized frame 246 of 250
# Extracted and resized frame 247 of 250
# Extracted and resized frame 248 of 250
# Extracted and resized frame 249 of 250
# Extracted and resized frame 250 of 250
# Done extracting and resizing frames.

# %%
import shutil
import os
from google.colab import files

def download_folder_as_zip(folder_path, zip_name):
    # Create a zip file
    shutil.make_archive(zip_name, 'zip', folder_path)

    # Download the zip file
    files.download(f"{zip_name}.zip")

# Example usage
folder_path = '/content/left_palm_frames'
zip_name = 'left_palm_frames'
download_folder_as_zip(folder_path, zip_name)

# %%
import cv2
import os
import math

def extract_and_resize_frames(video_path, output_folder, frame_count=250, frame_size=(64, 64)):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Capture the video
    video_capture = cv2.VideoCapture(video_path)

    # Check if video opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total number of frames in the video: {total_frames}")

    # Calculate the interval to evenly space the frame_count frames
    interval = max(1, total_frames // frame_count)
    print(f"Frame extraction interval: {interval}")

    frame_number = 0
    extracted_frames = 0

    while extracted_frames < frame_count and frame_number < total_frames:
        # Set the position of the next frame to read
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

        # Read the frame
        ret, frame = video_capture.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, frame_size)

        # Save the frame as an image file
        frame_filename = os.path.join(output_folder, f"rp_{extracted_frames:04d}.png")
        cv2.imwrite(frame_filename, resized_frame)

        # Print the status
        print(f"Extracted and resized frame {extracted_frames + 1} of {frame_count}")

        extracted_frames += 1
        frame_number += interval

    # Release the video capture object
    video_capture.release()
    print("Done extracting and resizing frames.")

# Example usage
video_path = '/content/rt_palm.mp4'
output_folder = 'right_palm_frames'
extract_and_resize_frames(video_path, output_folder)
# Out:
# Total number of frames in the video: 480
# Frame extraction interval: 1
# Extracted and resized frame 1 of 250
# Extracted and resized frame 2 of 250
# Extracted and resized frame 3 of 250
# Extracted and resized frame 4 of 250
# Extracted and resized frame 5 of 250
# Extracted and resized frame 6 of 250
# Extracted and resized frame 7 of 250
# Extracted and resized frame 8 of 250
# Extracted and resized frame 9 of 250
# Extracted and resized frame 10 of 250
# Extracted and resized frame 11 of 250
# Extracted and resized frame 12 of 250
# Extracted and resized frame 13 of 250
# Extracted and resized frame 14 of 250
# Extracted and resized frame 15 of 250
# Extracted and resized frame 16 of 250
# Extracted and resized frame 17 of 250
# Extracted and resized frame 18 of 250
# Extracted and resized frame 19 of 250
# Extracted and resized frame 20 of 250
# Extracted and resized frame 21 of 250
# Extracted and resized frame 22 of 250
# Extracted and resized frame 23 of 250
# Extracted and resized frame 24 of 250
# Extracted and resized frame 25 of 250
# Extracted and resized frame 26 of 250
# Extracted and resized frame 27 of 250
# Extracted and resized frame 28 of 250
# Extracted and resized frame 29 of 250
# Extracted and resized frame 30 of 250
# Extracted and resized frame 31 of 250
# Extracted and resized frame 32 of 250
# Extracted and resized frame 33 of 250
# Extracted and resized frame 34 of 250
# Extracted and resized frame 35 of 250
# Extracted and resized frame 36 of 250
# Extracted and resized frame 37 of 250
# Extracted and resized frame 38 of 250
# Extracted and resized frame 39 of 250
# Extracted and resized frame 40 of 250
# Extracted and resized frame 41 of 250
# Extracted and resized frame 42 of 250
# Extracted and resized frame 43 of 250
# Extracted and resized frame 44 of 250
# Extracted and resized frame 45 of 250
# Extracted and resized frame 46 of 250
# Extracted and resized frame 47 of 250
# Extracted and resized frame 48 of 250
# Extracted and resized frame 49 of 250
# Extracted and resized frame 50 of 250
# Extracted and resized frame 51 of 250
# Extracted and resized frame 52 of 250
# Extracted and resized frame 53 of 250
# Extracted and resized frame 54 of 250
# Extracted and resized frame 55 of 250
# Extracted and resized frame 56 of 250
# Extracted and resized frame 57 of 250
# Extracted and resized frame 58 of 250
# Extracted and resized frame 59 of 250
# Extracted and resized frame 60 of 250
# Extracted and resized frame 61 of 250
# Extracted and resized frame 62 of 250
# Extracted and resized frame 63 of 250
# Extracted and resized frame 64 of 250
# Extracted and resized frame 65 of 250
# Extracted and resized frame 66 of 250
# Extracted and resized frame 67 of 250
# Extracted and resized frame 68 of 250
# Extracted and resized frame 69 of 250
# Extracted and resized frame 70 of 250
# Extracted and resized frame 71 of 250
# Extracted and resized frame 72 of 250
# Extracted and resized frame 73 of 250
# Extracted and resized frame 74 of 250
# Extracted and resized frame 75 of 250
# Extracted and resized frame 76 of 250
# Extracted and resized frame 77 of 250
# Extracted and resized frame 78 of 250
# Extracted and resized frame 79 of 250
# Extracted and resized frame 80 of 250
# Extracted and resized frame 81 of 250
# Extracted and resized frame 82 of 250
# Extracted and resized frame 83 of 250
# Extracted and resized frame 84 of 250
# Extracted and resized frame 85 of 250
# Extracted and resized frame 86 of 250
# Extracted and resized frame 87 of 250
# Extracted and resized frame 88 of 250
# Extracted and resized frame 89 of 250
# Extracted and resized frame 90 of 250
# Extracted and resized frame 91 of 250
# Extracted and resized frame 92 of 250
# Extracted and resized frame 93 of 250
# Extracted and resized frame 94 of 250
# Extracted and resized frame 95 of 250
# Extracted and resized frame 96 of 250
# Extracted and resized frame 97 of 250
# Extracted and resized frame 98 of 250
# Extracted and resized frame 99 of 250
# Extracted and resized frame 100 of 250
# Extracted and resized frame 101 of 250
# Extracted and resized frame 102 of 250
# Extracted and resized frame 103 of 250
# Extracted and resized frame 104 of 250
# Extracted and resized frame 105 of 250
# Extracted and resized frame 106 of 250
# Extracted and resized frame 107 of 250
# Extracted and resized frame 108 of 250
# Extracted and resized frame 109 of 250
# Extracted and resized frame 110 of 250
# Extracted and resized frame 111 of 250
# Extracted and resized frame 112 of 250
# Extracted and resized frame 113 of 250
# Extracted and resized frame 114 of 250
# Extracted and resized frame 115 of 250
# Extracted and resized frame 116 of 250
# Extracted and resized frame 117 of 250
# Extracted and resized frame 118 of 250
# Extracted and resized frame 119 of 250
# Extracted and resized frame 120 of 250
# Extracted and resized frame 121 of 250
# Extracted and resized frame 122 of 250
# Extracted and resized frame 123 of 250
# Extracted and resized frame 124 of 250
# Extracted and resized frame 125 of 250
# Extracted and resized frame 126 of 250
# Extracted and resized frame 127 of 250
# Extracted and resized frame 128 of 250
# Extracted and resized frame 129 of 250
# Extracted and resized frame 130 of 250
# Extracted and resized frame 131 of 250
# Extracted and resized frame 132 of 250
# Extracted and resized frame 133 of 250
# Extracted and resized frame 134 of 250
# Extracted and resized frame 135 of 250
# Extracted and resized frame 136 of 250
# Extracted and resized frame 137 of 250
# Extracted and resized frame 138 of 250
# Extracted and resized frame 139 of 250
# Extracted and resized frame 140 of 250
# Extracted and resized frame 141 of 250
# Extracted and resized frame 142 of 250
# Extracted and resized frame 143 of 250
# Extracted and resized frame 144 of 250
# Extracted and resized frame 145 of 250
# Extracted and resized frame 146 of 250
# Extracted and resized frame 147 of 250
# Extracted and resized frame 148 of 250
# Extracted and resized frame 149 of 250
# Extracted and resized frame 150 of 250
# Extracted and resized frame 151 of 250
# Extracted and resized frame 152 of 250
# Extracted and resized frame 153 of 250
# Extracted and resized frame 154 of 250
# Extracted and resized frame 155 of 250
# Extracted and resized frame 156 of 250
# Extracted and resized frame 157 of 250
# Extracted and resized frame 158 of 250
# Extracted and resized frame 159 of 250
# Extracted and resized frame 160 of 250
# Extracted and resized frame 161 of 250
# Extracted and resized frame 162 of 250
# Extracted and resized frame 163 of 250
# Extracted and resized frame 164 of 250
# Extracted and resized frame 165 of 250
# Extracted and resized frame 166 of 250
# Extracted and resized frame 167 of 250
# Extracted and resized frame 168 of 250
# Extracted and resized frame 169 of 250
# Extracted and resized frame 170 of 250
# Extracted and resized frame 171 of 250
# Extracted and resized frame 172 of 250
# Extracted and resized frame 173 of 250
# Extracted and resized frame 174 of 250
# Extracted and resized frame 175 of 250
# Extracted and resized frame 176 of 250
# Extracted and resized frame 177 of 250
# Extracted and resized frame 178 of 250
# Extracted and resized frame 179 of 250
# Extracted and resized frame 180 of 250
# Extracted and resized frame 181 of 250
# Extracted and resized frame 182 of 250
# Extracted and resized frame 183 of 250
# Extracted and resized frame 184 of 250
# Extracted and resized frame 185 of 250
# Extracted and resized frame 186 of 250
# Extracted and resized frame 187 of 250
# Extracted and resized frame 188 of 250
# Extracted and resized frame 189 of 250
# Extracted and resized frame 190 of 250
# Extracted and resized frame 191 of 250
# Extracted and resized frame 192 of 250
# Extracted and resized frame 193 of 250
# Extracted and resized frame 194 of 250
# Extracted and resized frame 195 of 250
# Extracted and resized frame 196 of 250
# Extracted and resized frame 197 of 250
# Extracted and resized frame 198 of 250
# Extracted and resized frame 199 of 250
# Extracted and resized frame 200 of 250
# Extracted and resized frame 201 of 250
# Extracted and resized frame 202 of 250
# Extracted and resized frame 203 of 250
# Extracted and resized frame 204 of 250
# Extracted and resized frame 205 of 250
# Extracted and resized frame 206 of 250
# Extracted and resized frame 207 of 250
# Extracted and resized frame 208 of 250
# Extracted and resized frame 209 of 250
# Extracted and resized frame 210 of 250
# Extracted and resized frame 211 of 250
# Extracted and resized frame 212 of 250
# Extracted and resized frame 213 of 250
# Extracted and resized frame 214 of 250
# Extracted and resized frame 215 of 250
# Extracted and resized frame 216 of 250
# Extracted and resized frame 217 of 250
# Extracted and resized frame 218 of 250
# Extracted and resized frame 219 of 250
# Extracted and resized frame 220 of 250
# Extracted and resized frame 221 of 250
# Extracted and resized frame 222 of 250
# Extracted and resized frame 223 of 250
# Extracted and resized frame 224 of 250
# Extracted and resized frame 225 of 250
# Extracted and resized frame 226 of 250
# Extracted and resized frame 227 of 250
# Extracted and resized frame 228 of 250
# Extracted and resized frame 229 of 250
# Extracted and resized frame 230 of 250
# Extracted and resized frame 231 of 250
# Extracted and resized frame 232 of 250
# Extracted and resized frame 233 of 250
# Extracted and resized frame 234 of 250
# Extracted and resized frame 235 of 250
# Extracted and resized frame 236 of 250
# Extracted and resized frame 237 of 250
# Extracted and resized frame 238 of 250
# Extracted and resized frame 239 of 250
# Extracted and resized frame 240 of 250
# Extracted and resized frame 241 of 250
# Extracted and resized frame 242 of 250
# Extracted and resized frame 243 of 250
# Extracted and resized frame 244 of 250
# Extracted and resized frame 245 of 250
# Extracted and resized frame 246 of 250
# Extracted and resized frame 247 of 250
# Extracted and resized frame 248 of 250
# Extracted and resized frame 249 of 250
# Extracted and resized frame 250 of 250
# Done extracting and resizing frames.

# %%
import shutil
import os
from google.colab import files

def download_folder_as_zip(folder_path, zip_name):
    # Create a zip file
    shutil.make_archive(zip_name, 'zip', folder_path)

    # Download the zip file
    files.download(f"{zip_name}.zip")

# Example usage
folder_path = '/content/right_palm_frames'
zip_name = 'right_palm_frames'
download_folder_as_zip(folder_path, zip_name)

# %%
import cv2
import os
import math

def extract_and_resize_frames(video_path, output_folder, frame_count=250, frame_size=(64, 64)):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Capture the video
    video_capture = cv2.VideoCapture(video_path)

    # Check if video opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total number of frames in the video: {total_frames}")

    # Calculate the interval to evenly space the frame_count frames
    interval = max(1, total_frames // frame_count)
    print(f"Frame extraction interval: {interval}")

    frame_number = 0
    extracted_frames = 0

    while extracted_frames < frame_count and frame_number < total_frames:
        # Set the position of the next frame to read
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

        # Read the frame
        ret, frame = video_capture.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, frame_size)

        # Save the frame as an image file
        frame_filename = os.path.join(output_folder, f"lf_{extracted_frames:04d}.png")
        cv2.imwrite(frame_filename, resized_frame)

        # Print the status
        print(f"Extracted and resized frame {extracted_frames + 1} of {frame_count}")

        extracted_frames += 1
        frame_number += interval

    # Release the video capture object
    video_capture.release()
    print("Done extracting and resizing frames.")

# Example usage
video_path = '/content/left_fist.mp4'
output_folder = 'left_fist_frames'
extract_and_resize_frames(video_path, output_folder)
# Out:
# Total number of frames in the video: 282
# Frame extraction interval: 1
# Extracted and resized frame 1 of 250
# Extracted and resized frame 2 of 250
# Extracted and resized frame 3 of 250
# Extracted and resized frame 4 of 250
# Extracted and resized frame 5 of 250
# Extracted and resized frame 6 of 250
# Extracted and resized frame 7 of 250
# Extracted and resized frame 8 of 250
# Extracted and resized frame 9 of 250
# Extracted and resized frame 10 of 250
# Extracted and resized frame 11 of 250
# Extracted and resized frame 12 of 250
# Extracted and resized frame 13 of 250
# Extracted and resized frame 14 of 250
# Extracted and resized frame 15 of 250
# Extracted and resized frame 16 of 250
# Extracted and resized frame 17 of 250
# Extracted and resized frame 18 of 250
# Extracted and resized frame 19 of 250
# Extracted and resized frame 20 of 250
# Extracted and resized frame 21 of 250
# Extracted and resized frame 22 of 250
# Extracted and resized frame 23 of 250
# Extracted and resized frame 24 of 250
# Extracted and resized frame 25 of 250
# Extracted and resized frame 26 of 250
# Extracted and resized frame 27 of 250
# Extracted and resized frame 28 of 250
# Extracted and resized frame 29 of 250
# Extracted and resized frame 30 of 250
# Extracted and resized frame 31 of 250
# Extracted and resized frame 32 of 250
# Extracted and resized frame 33 of 250
# Extracted and resized frame 34 of 250
# Extracted and resized frame 35 of 250
# Extracted and resized frame 36 of 250
# Extracted and resized frame 37 of 250
# Extracted and resized frame 38 of 250
# Extracted and resized frame 39 of 250
# Extracted and resized frame 40 of 250
# Extracted and resized frame 41 of 250
# Extracted and resized frame 42 of 250
# Extracted and resized frame 43 of 250
# Extracted and resized frame 44 of 250
# Extracted and resized frame 45 of 250
# Extracted and resized frame 46 of 250
# Extracted and resized frame 47 of 250
# Extracted and resized frame 48 of 250
# Extracted and resized frame 49 of 250
# Extracted and resized frame 50 of 250
# Extracted and resized frame 51 of 250
# Extracted and resized frame 52 of 250
# Extracted and resized frame 53 of 250
# Extracted and resized frame 54 of 250
# Extracted and resized frame 55 of 250
# Extracted and resized frame 56 of 250
# Extracted and resized frame 57 of 250
# Extracted and resized frame 58 of 250
# Extracted and resized frame 59 of 250
# Extracted and resized frame 60 of 250
# Extracted and resized frame 61 of 250
# Extracted and resized frame 62 of 250
# Extracted and resized frame 63 of 250
# Extracted and resized frame 64 of 250
# Extracted and resized frame 65 of 250
# Extracted and resized frame 66 of 250
# Extracted and resized frame 67 of 250
# Extracted and resized frame 68 of 250
# Extracted and resized frame 69 of 250
# Extracted and resized frame 70 of 250
# Extracted and resized frame 71 of 250
# Extracted and resized frame 72 of 250
# Extracted and resized frame 73 of 250
# Extracted and resized frame 74 of 250
# Extracted and resized frame 75 of 250
# Extracted and resized frame 76 of 250
# Extracted and resized frame 77 of 250
# Extracted and resized frame 78 of 250
# Extracted and resized frame 79 of 250
# Extracted and resized frame 80 of 250
# Extracted and resized frame 81 of 250
# Extracted and resized frame 82 of 250
# Extracted and resized frame 83 of 250
# Extracted and resized frame 84 of 250
# Extracted and resized frame 85 of 250
# Extracted and resized frame 86 of 250
# Extracted and resized frame 87 of 250
# Extracted and resized frame 88 of 250
# Extracted and resized frame 89 of 250
# Extracted and resized frame 90 of 250
# Extracted and resized frame 91 of 250
# Extracted and resized frame 92 of 250
# Extracted and resized frame 93 of 250
# Extracted and resized frame 94 of 250
# Extracted and resized frame 95 of 250
# Extracted and resized frame 96 of 250
# Extracted and resized frame 97 of 250
# Extracted and resized frame 98 of 250
# Extracted and resized frame 99 of 250
# Extracted and resized frame 100 of 250
# Extracted and resized frame 101 of 250
# Extracted and resized frame 102 of 250
# Extracted and resized frame 103 of 250
# Extracted and resized frame 104 of 250
# Extracted and resized frame 105 of 250
# Extracted and resized frame 106 of 250
# Extracted and resized frame 107 of 250
# Extracted and resized frame 108 of 250
# Extracted and resized frame 109 of 250
# Extracted and resized frame 110 of 250
# Extracted and resized frame 111 of 250
# Extracted and resized frame 112 of 250
# Extracted and resized frame 113 of 250
# Extracted and resized frame 114 of 250
# Extracted and resized frame 115 of 250
# Extracted and resized frame 116 of 250
# Extracted and resized frame 117 of 250
# Extracted and resized frame 118 of 250
# Extracted and resized frame 119 of 250
# Extracted and resized frame 120 of 250
# Extracted and resized frame 121 of 250
# Extracted and resized frame 122 of 250
# Extracted and resized frame 123 of 250
# Extracted and resized frame 124 of 250
# Extracted and resized frame 125 of 250
# Extracted and resized frame 126 of 250
# Extracted and resized frame 127 of 250
# Extracted and resized frame 128 of 250
# Extracted and resized frame 129 of 250
# Extracted and resized frame 130 of 250
# Extracted and resized frame 131 of 250
# Extracted and resized frame 132 of 250
# Extracted and resized frame 133 of 250
# Extracted and resized frame 134 of 250
# Extracted and resized frame 135 of 250
# Extracted and resized frame 136 of 250
# Extracted and resized frame 137 of 250
# Extracted and resized frame 138 of 250
# Extracted and resized frame 139 of 250
# Extracted and resized frame 140 of 250
# Extracted and resized frame 141 of 250
# Extracted and resized frame 142 of 250
# Extracted and resized frame 143 of 250
# Extracted and resized frame 144 of 250
# Extracted and resized frame 145 of 250
# Extracted and resized frame 146 of 250
# Extracted and resized frame 147 of 250
# Extracted and resized frame 148 of 250
# Extracted and resized frame 149 of 250
# Extracted and resized frame 150 of 250
# Extracted and resized frame 151 of 250
# Extracted and resized frame 152 of 250
# Extracted and resized frame 153 of 250
# Extracted and resized frame 154 of 250
# Extracted and resized frame 155 of 250
# Extracted and resized frame 156 of 250
# Extracted and resized frame 157 of 250
# Extracted and resized frame 158 of 250
# Extracted and resized frame 159 of 250
# Extracted and resized frame 160 of 250
# Extracted and resized frame 161 of 250
# Extracted and resized frame 162 of 250
# Extracted and resized frame 163 of 250
# Extracted and resized frame 164 of 250
# Extracted and resized frame 165 of 250
# Extracted and resized frame 166 of 250
# Extracted and resized frame 167 of 250
# Extracted and resized frame 168 of 250
# Extracted and resized frame 169 of 250
# Extracted and resized frame 170 of 250
# Extracted and resized frame 171 of 250
# Extracted and resized frame 172 of 250
# Extracted and resized frame 173 of 250
# Extracted and resized frame 174 of 250
# Extracted and resized frame 175 of 250
# Extracted and resized frame 176 of 250
# Extracted and resized frame 177 of 250
# Extracted and resized frame 178 of 250
# Extracted and resized frame 179 of 250
# Extracted and resized frame 180 of 250
# Extracted and resized frame 181 of 250
# Extracted and resized frame 182 of 250
# Extracted and resized frame 183 of 250
# Extracted and resized frame 184 of 250
# Extracted and resized frame 185 of 250
# Extracted and resized frame 186 of 250
# Extracted and resized frame 187 of 250
# Extracted and resized frame 188 of 250
# Extracted and resized frame 189 of 250
# Extracted and resized frame 190 of 250
# Extracted and resized frame 191 of 250
# Extracted and resized frame 192 of 250
# Extracted and resized frame 193 of 250
# Extracted and resized frame 194 of 250
# Extracted and resized frame 195 of 250
# Extracted and resized frame 196 of 250
# Extracted and resized frame 197 of 250
# Extracted and resized frame 198 of 250
# Extracted and resized frame 199 of 250
# Extracted and resized frame 200 of 250
# Extracted and resized frame 201 of 250
# Extracted and resized frame 202 of 250
# Extracted and resized frame 203 of 250
# Extracted and resized frame 204 of 250
# Extracted and resized frame 205 of 250
# Extracted and resized frame 206 of 250
# Extracted and resized frame 207 of 250
# Extracted and resized frame 208 of 250
# Extracted and resized frame 209 of 250
# Extracted and resized frame 210 of 250
# Extracted and resized frame 211 of 250
# Extracted and resized frame 212 of 250
# Extracted and resized frame 213 of 250
# Extracted and resized frame 214 of 250
# Extracted and resized frame 215 of 250
# Extracted and resized frame 216 of 250
# Extracted and resized frame 217 of 250
# Extracted and resized frame 218 of 250
# Extracted and resized frame 219 of 250
# Extracted and resized frame 220 of 250
# Extracted and resized frame 221 of 250
# Extracted and resized frame 222 of 250
# Extracted and resized frame 223 of 250
# Extracted and resized frame 224 of 250
# Extracted and resized frame 225 of 250
# Extracted and resized frame 226 of 250
# Extracted and resized frame 227 of 250
# Extracted and resized frame 228 of 250
# Extracted and resized frame 229 of 250
# Extracted and resized frame 230 of 250
# Extracted and resized frame 231 of 250
# Extracted and resized frame 232 of 250
# Extracted and resized frame 233 of 250
# Extracted and resized frame 234 of 250
# Extracted and resized frame 235 of 250
# Extracted and resized frame 236 of 250
# Extracted and resized frame 237 of 250
# Extracted and resized frame 238 of 250
# Extracted and resized frame 239 of 250
# Extracted and resized frame 240 of 250
# Extracted and resized frame 241 of 250
# Extracted and resized frame 242 of 250
# Extracted and resized frame 243 of 250
# Extracted and resized frame 244 of 250
# Extracted and resized frame 245 of 250
# Extracted and resized frame 246 of 250
# Extracted and resized frame 247 of 250
# Extracted and resized frame 248 of 250
# Extracted and resized frame 249 of 250
# Extracted and resized frame 250 of 250
# Done extracting and resizing frames.

# %%
import shutil
import os
from google.colab import files

def download_folder_as_zip(folder_path, zip_name):
    # Create a zip file
    shutil.make_archive(zip_name, 'zip', folder_path)

    # Download the zip file
    files.download(f"{zip_name}.zip")

# Example usage
folder_path = '/content/left_fist_frames'
zip_name = 'left_fist_frames'
download_folder_as_zip(folder_path, zip_name)

# %%
import cv2
import os
import math

def extract_and_resize_frames(video_path, output_folder, frame_count=250, frame_size=(64, 64)):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Capture the video
    video_capture = cv2.VideoCapture(video_path)

    # Check if video opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total number of frames in the video: {total_frames}")

    # Calculate the interval to evenly space the frame_count frames
    interval = max(1, total_frames // frame_count)
    print(f"Frame extraction interval: {interval}")

    frame_number = 0
    extracted_frames = 0

    while extracted_frames < frame_count and frame_number < total_frames:
        # Set the position of the next frame to read
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

        # Read the frame
        ret, frame = video_capture.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, frame_size)

        # Save the frame as an image file
        frame_filename = os.path.join(output_folder, f"rf_{extracted_frames:04d}.png")
        cv2.imwrite(frame_filename, resized_frame)

        # Print the status
        print(f"Extracted and resized frame {extracted_frames + 1} of {frame_count}")

        extracted_frames += 1
        frame_number += interval

    # Release the video capture object
    video_capture.release()
    print("Done extracting and resizing frames.")

# Example usage
video_path = '/content/right_fist.mp4'
output_folder = 'right_fist_frames'
extract_and_resize_frames(video_path, output_folder)
# Out:
# Total number of frames in the video: 309
# Frame extraction interval: 1
# Extracted and resized frame 1 of 250
# Extracted and resized frame 2 of 250
# Extracted and resized frame 3 of 250
# Extracted and resized frame 4 of 250
# Extracted and resized frame 5 of 250
# Extracted and resized frame 6 of 250
# Extracted and resized frame 7 of 250
# Extracted and resized frame 8 of 250
# Extracted and resized frame 9 of 250
# Extracted and resized frame 10 of 250
# Extracted and resized frame 11 of 250
# Extracted and resized frame 12 of 250
# Extracted and resized frame 13 of 250
# Extracted and resized frame 14 of 250
# Extracted and resized frame 15 of 250
# Extracted and resized frame 16 of 250
# Extracted and resized frame 17 of 250
# Extracted and resized frame 18 of 250
# Extracted and resized frame 19 of 250
# Extracted and resized frame 20 of 250
# Extracted and resized frame 21 of 250
# Extracted and resized frame 22 of 250
# Extracted and resized frame 23 of 250
# Extracted and resized frame 24 of 250
# Extracted and resized frame 25 of 250
# Extracted and resized frame 26 of 250
# Extracted and resized frame 27 of 250
# Extracted and resized frame 28 of 250
# Extracted and resized frame 29 of 250
# Extracted and resized frame 30 of 250
# Extracted and resized frame 31 of 250
# Extracted and resized frame 32 of 250
# Extracted and resized frame 33 of 250
# Extracted and resized frame 34 of 250
# Extracted and resized frame 35 of 250
# Extracted and resized frame 36 of 250
# Extracted and resized frame 37 of 250
# Extracted and resized frame 38 of 250
# Extracted and resized frame 39 of 250
# Extracted and resized frame 40 of 250
# Extracted and resized frame 41 of 250
# Extracted and resized frame 42 of 250
# Extracted and resized frame 43 of 250
# Extracted and resized frame 44 of 250
# Extracted and resized frame 45 of 250
# Extracted and resized frame 46 of 250
# Extracted and resized frame 47 of 250
# Extracted and resized frame 48 of 250
# Extracted and resized frame 49 of 250
# Extracted and resized frame 50 of 250
# Extracted and resized frame 51 of 250
# Extracted and resized frame 52 of 250
# Extracted and resized frame 53 of 250
# Extracted and resized frame 54 of 250
# Extracted and resized frame 55 of 250
# Extracted and resized frame 56 of 250
# Extracted and resized frame 57 of 250
# Extracted and resized frame 58 of 250
# Extracted and resized frame 59 of 250
# Extracted and resized frame 60 of 250
# Extracted and resized frame 61 of 250
# Extracted and resized frame 62 of 250
# Extracted and resized frame 63 of 250
# Extracted and resized frame 64 of 250
# Extracted and resized frame 65 of 250
# Extracted and resized frame 66 of 250
# Extracted and resized frame 67 of 250
# Extracted and resized frame 68 of 250
# Extracted and resized frame 69 of 250
# Extracted and resized frame 70 of 250
# Extracted and resized frame 71 of 250
# Extracted and resized frame 72 of 250
# Extracted and resized frame 73 of 250
# Extracted and resized frame 74 of 250
# Extracted and resized frame 75 of 250
# Extracted and resized frame 76 of 250
# Extracted and resized frame 77 of 250
# Extracted and resized frame 78 of 250
# Extracted and resized frame 79 of 250
# Extracted and resized frame 80 of 250
# Extracted and resized frame 81 of 250
# Extracted and resized frame 82 of 250
# Extracted and resized frame 83 of 250
# Extracted and resized frame 84 of 250
# Extracted and resized frame 85 of 250
# Extracted and resized frame 86 of 250
# Extracted and resized frame 87 of 250
# Extracted and resized frame 88 of 250
# Extracted and resized frame 89 of 250
# Extracted and resized frame 90 of 250
# Extracted and resized frame 91 of 250
# Extracted and resized frame 92 of 250
# Extracted and resized frame 93 of 250
# Extracted and resized frame 94 of 250
# Extracted and resized frame 95 of 250
# Extracted and resized frame 96 of 250
# Extracted and resized frame 97 of 250
# Extracted and resized frame 98 of 250
# Extracted and resized frame 99 of 250
# Extracted and resized frame 100 of 250
# Extracted and resized frame 101 of 250
# Extracted and resized frame 102 of 250
# Extracted and resized frame 103 of 250
# Extracted and resized frame 104 of 250
# Extracted and resized frame 105 of 250
# Extracted and resized frame 106 of 250
# Extracted and resized frame 107 of 250
# Extracted and resized frame 108 of 250
# Extracted and resized frame 109 of 250
# Extracted and resized frame 110 of 250
# Extracted and resized frame 111 of 250
# Extracted and resized frame 112 of 250
# Extracted and resized frame 113 of 250
# Extracted and resized frame 114 of 250
# Extracted and resized frame 115 of 250
# Extracted and resized frame 116 of 250
# Extracted and resized frame 117 of 250
# Extracted and resized frame 118 of 250
# Extracted and resized frame 119 of 250
# Extracted and resized frame 120 of 250
# Extracted and resized frame 121 of 250
# Extracted and resized frame 122 of 250
# Extracted and resized frame 123 of 250
# Extracted and resized frame 124 of 250
# Extracted and resized frame 125 of 250
# Extracted and resized frame 126 of 250
# Extracted and resized frame 127 of 250
# Extracted and resized frame 128 of 250
# Extracted and resized frame 129 of 250
# Extracted and resized frame 130 of 250
# Extracted and resized frame 131 of 250
# Extracted and resized frame 132 of 250
# Extracted and resized frame 133 of 250
# Extracted and resized frame 134 of 250
# Extracted and resized frame 135 of 250
# Extracted and resized frame 136 of 250
# Extracted and resized frame 137 of 250
# Extracted and resized frame 138 of 250
# Extracted and resized frame 139 of 250
# Extracted and resized frame 140 of 250
# Extracted and resized frame 141 of 250
# Extracted and resized frame 142 of 250
# Extracted and resized frame 143 of 250
# Extracted and resized frame 144 of 250
# Extracted and resized frame 145 of 250
# Extracted and resized frame 146 of 250
# Extracted and resized frame 147 of 250
# Extracted and resized frame 148 of 250
# Extracted and resized frame 149 of 250
# Extracted and resized frame 150 of 250
# Extracted and resized frame 151 of 250
# Extracted and resized frame 152 of 250
# Extracted and resized frame 153 of 250
# Extracted and resized frame 154 of 250
# Extracted and resized frame 155 of 250
# Extracted and resized frame 156 of 250
# Extracted and resized frame 157 of 250
# Extracted and resized frame 158 of 250
# Extracted and resized frame 159 of 250
# Extracted and resized frame 160 of 250
# Extracted and resized frame 161 of 250
# Extracted and resized frame 162 of 250
# Extracted and resized frame 163 of 250
# Extracted and resized frame 164 of 250
# Extracted and resized frame 165 of 250
# Extracted and resized frame 166 of 250
# Extracted and resized frame 167 of 250
# Extracted and resized frame 168 of 250
# Extracted and resized frame 169 of 250
# Extracted and resized frame 170 of 250
# Extracted and resized frame 171 of 250
# Extracted and resized frame 172 of 250
# Extracted and resized frame 173 of 250
# Extracted and resized frame 174 of 250
# Extracted and resized frame 175 of 250
# Extracted and resized frame 176 of 250
# Extracted and resized frame 177 of 250
# Extracted and resized frame 178 of 250
# Extracted and resized frame 179 of 250
# Extracted and resized frame 180 of 250
# Extracted and resized frame 181 of 250
# Extracted and resized frame 182 of 250
# Extracted and resized frame 183 of 250
# Extracted and resized frame 184 of 250
# Extracted and resized frame 185 of 250
# Extracted and resized frame 186 of 250
# Extracted and resized frame 187 of 250
# Extracted and resized frame 188 of 250
# Extracted and resized frame 189 of 250
# Extracted and resized frame 190 of 250
# Extracted and resized frame 191 of 250
# Extracted and resized frame 192 of 250
# Extracted and resized frame 193 of 250
# Extracted and resized frame 194 of 250
# Extracted and resized frame 195 of 250
# Extracted and resized frame 196 of 250
# Extracted and resized frame 197 of 250
# Extracted and resized frame 198 of 250
# Extracted and resized frame 199 of 250
# Extracted and resized frame 200 of 250
# Extracted and resized frame 201 of 250
# Extracted and resized frame 202 of 250
# Extracted and resized frame 203 of 250
# Extracted and resized frame 204 of 250
# Extracted and resized frame 205 of 250
# Extracted and resized frame 206 of 250
# Extracted and resized frame 207 of 250
# Extracted and resized frame 208 of 250
# Extracted and resized frame 209 of 250
# Extracted and resized frame 210 of 250
# Extracted and resized frame 211 of 250
# Extracted and resized frame 212 of 250
# Extracted and resized frame 213 of 250
# Extracted and resized frame 214 of 250
# Extracted and resized frame 215 of 250
# Extracted and resized frame 216 of 250
# Extracted and resized frame 217 of 250
# Extracted and resized frame 218 of 250
# Extracted and resized frame 219 of 250
# Extracted and resized frame 220 of 250
# Extracted and resized frame 221 of 250
# Extracted and resized frame 222 of 250
# Extracted and resized frame 223 of 250
# Extracted and resized frame 224 of 250
# Extracted and resized frame 225 of 250
# Extracted and resized frame 226 of 250
# Extracted and resized frame 227 of 250
# Extracted and resized frame 228 of 250
# Extracted and resized frame 229 of 250
# Extracted and resized frame 230 of 250
# Extracted and resized frame 231 of 250
# Extracted and resized frame 232 of 250
# Extracted and resized frame 233 of 250
# Extracted and resized frame 234 of 250
# Extracted and resized frame 235 of 250
# Extracted and resized frame 236 of 250
# Extracted and resized frame 237 of 250
# Extracted and resized frame 238 of 250
# Extracted and resized frame 239 of 250
# Extracted and resized frame 240 of 250
# Extracted and resized frame 241 of 250
# Extracted and resized frame 242 of 250
# Extracted and resized frame 243 of 250
# Extracted and resized frame 244 of 250
# Extracted and resized frame 245 of 250
# Extracted and resized frame 246 of 250
# Extracted and resized frame 247 of 250
# Extracted and resized frame 248 of 250
# Extracted and resized frame 249 of 250
# Extracted and resized frame 250 of 250
# Done extracting and resizing frames.

# %%
import shutil
import os
from google.colab import files

def download_folder_as_zip(folder_path, zip_name):
    # Create a zip file
    shutil.make_archive(zip_name, 'zip', folder_path)

    # Download the zip file
    files.download(f"{zip_name}.zip")

# Example usage
folder_path = '/content/right_fist_frames'
zip_name = 'right_fist_frames'
download_folder_as_zip(folder_path, zip_name)

# %%
import cv2
import os
import math

def extract_and_resize_frames(video_path, output_folder, frame_count=250, frame_size=(64, 64)):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Capture the video
    video_capture = cv2.VideoCapture(video_path)

    # Check if video opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total number of frames in the video: {total_frames}")

    # Calculate the interval to evenly space the frame_count frames
    interval = max(1, total_frames // frame_count)
    print(f"Frame extraction interval: {interval}")

    frame_number = 0
    extracted_frames = 0

    while extracted_frames < frame_count and frame_number < total_frames:
        # Set the position of the next frame to read
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

        # Read the frame
        ret, frame = video_capture.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, frame_size)

        # Save the frame as an image file
        frame_filename = os.path.join(output_folder, f"lt_{extracted_frames:04d}.png")
        cv2.imwrite(frame_filename, resized_frame)

        # Print the status
        print(f"Extracted and resized frame {extracted_frames + 1} of {frame_count}")

        extracted_frames += 1
        frame_number += interval

    # Release the video capture object
    video_capture.release()
    print("Done extracting and resizing frames.")

# Example usage
video_path = '/content/left_thumbsup.mp4'
output_folder = 'left_thumbs_frames'
extract_and_resize_frames(video_path, output_folder)
# Out:
# Total number of frames in the video: 281
# Frame extraction interval: 1
# Extracted and resized frame 1 of 250
# Extracted and resized frame 2 of 250
# Extracted and resized frame 3 of 250
# Extracted and resized frame 4 of 250
# Extracted and resized frame 5 of 250
# Extracted and resized frame 6 of 250
# Extracted and resized frame 7 of 250
# Extracted and resized frame 8 of 250
# Extracted and resized frame 9 of 250
# Extracted and resized frame 10 of 250
# Extracted and resized frame 11 of 250
# Extracted and resized frame 12 of 250
# Extracted and resized frame 13 of 250
# Extracted and resized frame 14 of 250
# Extracted and resized frame 15 of 250
# Extracted and resized frame 16 of 250
# Extracted and resized frame 17 of 250
# Extracted and resized frame 18 of 250
# Extracted and resized frame 19 of 250
# Extracted and resized frame 20 of 250
# Extracted and resized frame 21 of 250
# Extracted and resized frame 22 of 250
# Extracted and resized frame 23 of 250
# Extracted and resized frame 24 of 250
# Extracted and resized frame 25 of 250
# Extracted and resized frame 26 of 250
# Extracted and resized frame 27 of 250
# Extracted and resized frame 28 of 250
# Extracted and resized frame 29 of 250
# Extracted and resized frame 30 of 250
# Extracted and resized frame 31 of 250
# Extracted and resized frame 32 of 250
# Extracted and resized frame 33 of 250
# Extracted and resized frame 34 of 250
# Extracted and resized frame 35 of 250
# Extracted and resized frame 36 of 250
# Extracted and resized frame 37 of 250
# Extracted and resized frame 38 of 250
# Extracted and resized frame 39 of 250
# Extracted and resized frame 40 of 250
# Extracted and resized frame 41 of 250
# Extracted and resized frame 42 of 250
# Extracted and resized frame 43 of 250
# Extracted and resized frame 44 of 250
# Extracted and resized frame 45 of 250
# Extracted and resized frame 46 of 250
# Extracted and resized frame 47 of 250
# Extracted and resized frame 48 of 250
# Extracted and resized frame 49 of 250
# Extracted and resized frame 50 of 250
# Extracted and resized frame 51 of 250
# Extracted and resized frame 52 of 250
# Extracted and resized frame 53 of 250
# Extracted and resized frame 54 of 250
# Extracted and resized frame 55 of 250
# Extracted and resized frame 56 of 250
# Extracted and resized frame 57 of 250
# Extracted and resized frame 58 of 250
# Extracted and resized frame 59 of 250
# Extracted and resized frame 60 of 250
# Extracted and resized frame 61 of 250
# Extracted and resized frame 62 of 250
# Extracted and resized frame 63 of 250
# Extracted and resized frame 64 of 250
# Extracted and resized frame 65 of 250
# Extracted and resized frame 66 of 250
# Extracted and resized frame 67 of 250
# Extracted and resized frame 68 of 250
# Extracted and resized frame 69 of 250
# Extracted and resized frame 70 of 250
# Extracted and resized frame 71 of 250
# Extracted and resized frame 72 of 250
# Extracted and resized frame 73 of 250
# Extracted and resized frame 74 of 250
# Extracted and resized frame 75 of 250
# Extracted and resized frame 76 of 250
# Extracted and resized frame 77 of 250
# Extracted and resized frame 78 of 250
# Extracted and resized frame 79 of 250
# Extracted and resized frame 80 of 250
# Extracted and resized frame 81 of 250
# Extracted and resized frame 82 of 250
# Extracted and resized frame 83 of 250
# Extracted and resized frame 84 of 250
# Extracted and resized frame 85 of 250
# Extracted and resized frame 86 of 250
# Extracted and resized frame 87 of 250
# Extracted and resized frame 88 of 250
# Extracted and resized frame 89 of 250
# Extracted and resized frame 90 of 250
# Extracted and resized frame 91 of 250
# Extracted and resized frame 92 of 250
# Extracted and resized frame 93 of 250
# Extracted and resized frame 94 of 250
# Extracted and resized frame 95 of 250
# Extracted and resized frame 96 of 250
# Extracted and resized frame 97 of 250
# Extracted and resized frame 98 of 250
# Extracted and resized frame 99 of 250
# Extracted and resized frame 100 of 250
# Extracted and resized frame 101 of 250
# Extracted and resized frame 102 of 250
# Extracted and resized frame 103 of 250
# Extracted and resized frame 104 of 250
# Extracted and resized frame 105 of 250
# Extracted and resized frame 106 of 250
# Extracted and resized frame 107 of 250
# Extracted and resized frame 108 of 250
# Extracted and resized frame 109 of 250
# Extracted and resized frame 110 of 250
# Extracted and resized frame 111 of 250
# Extracted and resized frame 112 of 250
# Extracted and resized frame 113 of 250
# Extracted and resized frame 114 of 250
# Extracted and resized frame 115 of 250
# Extracted and resized frame 116 of 250
# Extracted and resized frame 117 of 250
# Extracted and resized frame 118 of 250
# Extracted and resized frame 119 of 250
# Extracted and resized frame 120 of 250
# Extracted and resized frame 121 of 250
# Extracted and resized frame 122 of 250
# Extracted and resized frame 123 of 250
# Extracted and resized frame 124 of 250
# Extracted and resized frame 125 of 250
# Extracted and resized frame 126 of 250
# Extracted and resized frame 127 of 250
# Extracted and resized frame 128 of 250
# Extracted and resized frame 129 of 250
# Extracted and resized frame 130 of 250
# Extracted and resized frame 131 of 250
# Extracted and resized frame 132 of 250
# Extracted and resized frame 133 of 250
# Extracted and resized frame 134 of 250
# Extracted and resized frame 135 of 250
# Extracted and resized frame 136 of 250
# Extracted and resized frame 137 of 250
# Extracted and resized frame 138 of 250
# Extracted and resized frame 139 of 250
# Extracted and resized frame 140 of 250
# Extracted and resized frame 141 of 250
# Extracted and resized frame 142 of 250
# Extracted and resized frame 143 of 250
# Extracted and resized frame 144 of 250
# Extracted and resized frame 145 of 250
# Extracted and resized frame 146 of 250
# Extracted and resized frame 147 of 250
# Extracted and resized frame 148 of 250
# Extracted and resized frame 149 of 250
# Extracted and resized frame 150 of 250
# Extracted and resized frame 151 of 250
# Extracted and resized frame 152 of 250
# Extracted and resized frame 153 of 250
# Extracted and resized frame 154 of 250
# Extracted and resized frame 155 of 250
# Extracted and resized frame 156 of 250
# Extracted and resized frame 157 of 250
# Extracted and resized frame 158 of 250
# Extracted and resized frame 159 of 250
# Extracted and resized frame 160 of 250
# Extracted and resized frame 161 of 250
# Extracted and resized frame 162 of 250
# Extracted and resized frame 163 of 250
# Extracted and resized frame 164 of 250
# Extracted and resized frame 165 of 250
# Extracted and resized frame 166 of 250
# Extracted and resized frame 167 of 250
# Extracted and resized frame 168 of 250
# Extracted and resized frame 169 of 250
# Extracted and resized frame 170 of 250
# Extracted and resized frame 171 of 250
# Extracted and resized frame 172 of 250
# Extracted and resized frame 173 of 250
# Extracted and resized frame 174 of 250
# Extracted and resized frame 175 of 250
# Extracted and resized frame 176 of 250
# Extracted and resized frame 177 of 250
# Extracted and resized frame 178 of 250
# Extracted and resized frame 179 of 250
# Extracted and resized frame 180 of 250
# Extracted and resized frame 181 of 250
# Extracted and resized frame 182 of 250
# Extracted and resized frame 183 of 250
# Extracted and resized frame 184 of 250
# Extracted and resized frame 185 of 250
# Extracted and resized frame 186 of 250
# Extracted and resized frame 187 of 250
# Extracted and resized frame 188 of 250
# Extracted and resized frame 189 of 250
# Extracted and resized frame 190 of 250
# Extracted and resized frame 191 of 250
# Extracted and resized frame 192 of 250
# Extracted and resized frame 193 of 250
# Extracted and resized frame 194 of 250
# Extracted and resized frame 195 of 250
# Extracted and resized frame 196 of 250
# Extracted and resized frame 197 of 250
# Extracted and resized frame 198 of 250
# Extracted and resized frame 199 of 250
# Extracted and resized frame 200 of 250
# Extracted and resized frame 201 of 250
# Extracted and resized frame 202 of 250
# Extracted and resized frame 203 of 250
# Extracted and resized frame 204 of 250
# Extracted and resized frame 205 of 250
# Extracted and resized frame 206 of 250
# Extracted and resized frame 207 of 250
# Extracted and resized frame 208 of 250
# Extracted and resized frame 209 of 250
# Extracted and resized frame 210 of 250
# Extracted and resized frame 211 of 250
# Extracted and resized frame 212 of 250
# Extracted and resized frame 213 of 250
# Extracted and resized frame 214 of 250
# Extracted and resized frame 215 of 250
# Extracted and resized frame 216 of 250
# Extracted and resized frame 217 of 250
# Extracted and resized frame 218 of 250
# Extracted and resized frame 219 of 250
# Extracted and resized frame 220 of 250
# Extracted and resized frame 221 of 250
# Extracted and resized frame 222 of 250
# Extracted and resized frame 223 of 250
# Extracted and resized frame 224 of 250
# Extracted and resized frame 225 of 250
# Extracted and resized frame 226 of 250
# Extracted and resized frame 227 of 250
# Extracted and resized frame 228 of 250
# Extracted and resized frame 229 of 250
# Extracted and resized frame 230 of 250
# Extracted and resized frame 231 of 250
# Extracted and resized frame 232 of 250
# Extracted and resized frame 233 of 250
# Extracted and resized frame 234 of 250
# Extracted and resized frame 235 of 250
# Extracted and resized frame 236 of 250
# Extracted and resized frame 237 of 250
# Extracted and resized frame 238 of 250
# Extracted and resized frame 239 of 250
# Extracted and resized frame 240 of 250
# Extracted and resized frame 241 of 250
# Extracted and resized frame 242 of 250
# Extracted and resized frame 243 of 250
# Extracted and resized frame 244 of 250
# Extracted and resized frame 245 of 250
# Extracted and resized frame 246 of 250
# Extracted and resized frame 247 of 250
# Extracted and resized frame 248 of 250
# Extracted and resized frame 249 of 250
# Extracted and resized frame 250 of 250
# Done extracting and resizing frames.

# %%
import shutil
import os
from google.colab import files

def download_folder_as_zip(folder_path, zip_name):
    # Create a zip file
    shutil.make_archive(zip_name, 'zip', folder_path)

    # Download the zip file
    files.download(f"{zip_name}.zip")

# Example usage
folder_path = '/content/left_thumbs_frames'
zip_name = 'left_thumbs_frames'
download_folder_as_zip(folder_path, zip_name)

# %%
import cv2
import os
import math

def extract_and_resize_frames(video_path, output_folder, frame_count=250, frame_size=(64, 64)):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Capture the video
    video_capture = cv2.VideoCapture(video_path)

    # Check if video opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    # Get the total number of frames in the video
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total number of frames in the video: {total_frames}")

    # Calculate the interval to evenly space the frame_count frames
    interval = max(1, total_frames // frame_count)
    print(f"Frame extraction interval: {interval}")

    frame_number = 0
    extracted_frames = 0

    while extracted_frames < frame_count and frame_number < total_frames:
        # Set the position of the next frame to read
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

        # Read the frame
        ret, frame = video_capture.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, frame_size)

        # Save the frame as an image file
        frame_filename = os.path.join(output_folder, f"rt_{extracted_frames:04d}.png")
        cv2.imwrite(frame_filename, resized_frame)

        # Print the status
        print(f"Extracted and resized frame {extracted_frames + 1} of {frame_count}")

        extracted_frames += 1
        frame_number += interval

    # Release the video capture object
    video_capture.release()
    print("Done extracting and resizing frames.")

# Example usage
video_path = '/content/right_thumbs.mp4'
output_folder = 'right_thumbs'
extract_and_resize_frames(video_path, output_folder)
# Out:
# Total number of frames in the video: 309
# Frame extraction interval: 1
# Extracted and resized frame 1 of 250
# Extracted and resized frame 2 of 250
# Extracted and resized frame 3 of 250
# Extracted and resized frame 4 of 250
# Extracted and resized frame 5 of 250
# Extracted and resized frame 6 of 250
# Extracted and resized frame 7 of 250
# Extracted and resized frame 8 of 250
# Extracted and resized frame 9 of 250
# Extracted and resized frame 10 of 250
# Extracted and resized frame 11 of 250
# Extracted and resized frame 12 of 250
# Extracted and resized frame 13 of 250
# Extracted and resized frame 14 of 250
# Extracted and resized frame 15 of 250
# Extracted and resized frame 16 of 250
# Extracted and resized frame 17 of 250
# Extracted and resized frame 18 of 250
# Extracted and resized frame 19 of 250
# Extracted and resized frame 20 of 250
# Extracted and resized frame 21 of 250
# Extracted and resized frame 22 of 250
# Extracted and resized frame 23 of 250
# Extracted and resized frame 24 of 250
# Extracted and resized frame 25 of 250
# Extracted and resized frame 26 of 250
# Extracted and resized frame 27 of 250
# Extracted and resized frame 28 of 250
# Extracted and resized frame 29 of 250
# Extracted and resized frame 30 of 250
# Extracted and resized frame 31 of 250
# Extracted and resized frame 32 of 250
# Extracted and resized frame 33 of 250
# Extracted and resized frame 34 of 250
# Extracted and resized frame 35 of 250
# Extracted and resized frame 36 of 250
# Extracted and resized frame 37 of 250
# Extracted and resized frame 38 of 250
# Extracted and resized frame 39 of 250
# Extracted and resized frame 40 of 250
# Extracted and resized frame 41 of 250
# Extracted and resized frame 42 of 250
# Extracted and resized frame 43 of 250
# Extracted and resized frame 44 of 250
# Extracted and resized frame 45 of 250
# Extracted and resized frame 46 of 250
# Extracted and resized frame 47 of 250
# Extracted and resized frame 48 of 250
# Extracted and resized frame 49 of 250
# Extracted and resized frame 50 of 250
# Extracted and resized frame 51 of 250
# Extracted and resized frame 52 of 250
# Extracted and resized frame 53 of 250
# Extracted and resized frame 54 of 250
# Extracted and resized frame 55 of 250
# Extracted and resized frame 56 of 250
# Extracted and resized frame 57 of 250
# Extracted and resized frame 58 of 250
# Extracted and resized frame 59 of 250
# Extracted and resized frame 60 of 250
# Extracted and resized frame 61 of 250
# Extracted and resized frame 62 of 250
# Extracted and resized frame 63 of 250
# Extracted and resized frame 64 of 250
# Extracted and resized frame 65 of 250
# Extracted and resized frame 66 of 250
# Extracted and resized frame 67 of 250
# Extracted and resized frame 68 of 250
# Extracted and resized frame 69 of 250
# Extracted and resized frame 70 of 250
# Extracted and resized frame 71 of 250
# Extracted and resized frame 72 of 250
# Extracted and resized frame 73 of 250
# Extracted and resized frame 74 of 250
# Extracted and resized frame 75 of 250
# Extracted and resized frame 76 of 250
# Extracted and resized frame 77 of 250
# Extracted and resized frame 78 of 250
# Extracted and resized frame 79 of 250
# Extracted and resized frame 80 of 250
# Extracted and resized frame 81 of 250
# Extracted and resized frame 82 of 250
# Extracted and resized frame 83 of 250
# Extracted and resized frame 84 of 250
# Extracted and resized frame 85 of 250
# Extracted and resized frame 86 of 250
# Extracted and resized frame 87 of 250
# Extracted and resized frame 88 of 250
# Extracted and resized frame 89 of 250
# Extracted and resized frame 90 of 250
# Extracted and resized frame 91 of 250
# Extracted and resized frame 92 of 250
# Extracted and resized frame 93 of 250
# Extracted and resized frame 94 of 250
# Extracted and resized frame 95 of 250
# Extracted and resized frame 96 of 250
# Extracted and resized frame 97 of 250
# Extracted and resized frame 98 of 250
# Extracted and resized frame 99 of 250
# Extracted and resized frame 100 of 250
# Extracted and resized frame 101 of 250
# Extracted and resized frame 102 of 250
# Extracted and resized frame 103 of 250
# Extracted and resized frame 104 of 250
# Extracted and resized frame 105 of 250
# Extracted and resized frame 106 of 250
# Extracted and resized frame 107 of 250
# Extracted and resized frame 108 of 250
# Extracted and resized frame 109 of 250
# Extracted and resized frame 110 of 250
# Extracted and resized frame 111 of 250
# Extracted and resized frame 112 of 250
# Extracted and resized frame 113 of 250
# Extracted and resized frame 114 of 250
# Extracted and resized frame 115 of 250
# Extracted and resized frame 116 of 250
# Extracted and resized frame 117 of 250
# Extracted and resized frame 118 of 250
# Extracted and resized frame 119 of 250
# Extracted and resized frame 120 of 250
# Extracted and resized frame 121 of 250
# Extracted and resized frame 122 of 250
# Extracted and resized frame 123 of 250
# Extracted and resized frame 124 of 250
# Extracted and resized frame 125 of 250
# Extracted and resized frame 126 of 250
# Extracted and resized frame 127 of 250
# Extracted and resized frame 128 of 250
# Extracted and resized frame 129 of 250
# Extracted and resized frame 130 of 250
# Extracted and resized frame 131 of 250
# Extracted and resized frame 132 of 250
# Extracted and resized frame 133 of 250
# Extracted and resized frame 134 of 250
# Extracted and resized frame 135 of 250
# Extracted and resized frame 136 of 250
# Extracted and resized frame 137 of 250
# Extracted and resized frame 138 of 250
# Extracted and resized frame 139 of 250
# Extracted and resized frame 140 of 250
# Extracted and resized frame 141 of 250
# Extracted and resized frame 142 of 250
# Extracted and resized frame 143 of 250
# Extracted and resized frame 144 of 250
# Extracted and resized frame 145 of 250
# Extracted and resized frame 146 of 250
# Extracted and resized frame 147 of 250
# Extracted and resized frame 148 of 250
# Extracted and resized frame 149 of 250
# Extracted and resized frame 150 of 250
# Extracted and resized frame 151 of 250
# Extracted and resized frame 152 of 250
# Extracted and resized frame 153 of 250
# Extracted and resized frame 154 of 250
# Extracted and resized frame 155 of 250
# Extracted and resized frame 156 of 250
# Extracted and resized frame 157 of 250
# Extracted and resized frame 158 of 250
# Extracted and resized frame 159 of 250
# Extracted and resized frame 160 of 250
# Extracted and resized frame 161 of 250
# Extracted and resized frame 162 of 250
# Extracted and resized frame 163 of 250
# Extracted and resized frame 164 of 250
# Extracted and resized frame 165 of 250
# Extracted and resized frame 166 of 250
# Extracted and resized frame 167 of 250
# Extracted and resized frame 168 of 250
# Extracted and resized frame 169 of 250
# Extracted and resized frame 170 of 250
# Extracted and resized frame 171 of 250
# Extracted and resized frame 172 of 250
# Extracted and resized frame 173 of 250
# Extracted and resized frame 174 of 250
# Extracted and resized frame 175 of 250
# Extracted and resized frame 176 of 250
# Extracted and resized frame 177 of 250
# Extracted and resized frame 178 of 250
# Extracted and resized frame 179 of 250
# Extracted and resized frame 180 of 250
# Extracted and resized frame 181 of 250
# Extracted and resized frame 182 of 250
# Extracted and resized frame 183 of 250
# Extracted and resized frame 184 of 250
# Extracted and resized frame 185 of 250
# Extracted and resized frame 186 of 250
# Extracted and resized frame 187 of 250
# Extracted and resized frame 188 of 250
# Extracted and resized frame 189 of 250
# Extracted and resized frame 190 of 250
# Extracted and resized frame 191 of 250
# Extracted and resized frame 192 of 250
# Extracted and resized frame 193 of 250
# Extracted and resized frame 194 of 250
# Extracted and resized frame 195 of 250
# Extracted and resized frame 196 of 250
# Extracted and resized frame 197 of 250
# Extracted and resized frame 198 of 250
# Extracted and resized frame 199 of 250
# Extracted and resized frame 200 of 250
# Extracted and resized frame 201 of 250
# Extracted and resized frame 202 of 250
# Extracted and resized frame 203 of 250
# Extracted and resized frame 204 of 250
# Extracted and resized frame 205 of 250
# Extracted and resized frame 206 of 250
# Extracted and resized frame 207 of 250
# Extracted and resized frame 208 of 250
# Extracted and resized frame 209 of 250
# Extracted and resized frame 210 of 250
# Extracted and resized frame 211 of 250
# Extracted and resized frame 212 of 250
# Extracted and resized frame 213 of 250
# Extracted and resized frame 214 of 250
# Extracted and resized frame 215 of 250
# Extracted and resized frame 216 of 250
# Extracted and resized frame 217 of 250
# Extracted and resized frame 218 of 250
# Extracted and resized frame 219 of 250
# Extracted and resized frame 220 of 250
# Extracted and resized frame 221 of 250
# Extracted and resized frame 222 of 250
# Extracted and resized frame 223 of 250
# Extracted and resized frame 224 of 250
# Extracted and resized frame 225 of 250
# Extracted and resized frame 226 of 250
# Extracted and resized frame 227 of 250
# Extracted and resized frame 228 of 250
# Extracted and resized frame 229 of 250
# Extracted and resized frame 230 of 250
# Extracted and resized frame 231 of 250
# Extracted and resized frame 232 of 250
# Extracted and resized frame 233 of 250
# Extracted and resized frame 234 of 250
# Extracted and resized frame 235 of 250
# Extracted and resized frame 236 of 250
# Extracted and resized frame 237 of 250
# Extracted and resized frame 238 of 250
# Extracted and resized frame 239 of 250
# Extracted and resized frame 240 of 250
# Extracted and resized frame 241 of 250
# Extracted and resized frame 242 of 250
# Extracted and resized frame 243 of 250
# Extracted and resized frame 244 of 250
# Extracted and resized frame 245 of 250
# Extracted and resized frame 246 of 250
# Extracted and resized frame 247 of 250
# Extracted and resized frame 248 of 250
# Extracted and resized frame 249 of 250
# Extracted and resized frame 250 of 250
# Done extracting and resizing frames.

# %%
import shutil
import os
from google.colab import files

def download_folder_as_zip(folder_path, zip_name):
    # Create a zip file
    shutil.make_archive(zip_name, 'zip', folder_path)

    # Download the zip file
    files.download(f"{zip_name}.zip")

# Example usage
folder_path = '/content/right_thumbs'
zip_name = 'right_thumbs'
download_folder_as_zip(folder_path, zip_name)
